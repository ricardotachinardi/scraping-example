# %% [markdown]
# # A ideia desse notebook é explorar um pouco as requests envolvidas no projeto

# %%
import requests
import json

# %%
# mesmos valores em todas as requests
headers = {
	"Accept": "application/json",
	"Accept-Encoding": "gzip, deflate",
}

# %% [markdown]
# ## Podemos obter o id de outros valores mobiliarios, mas não é necessário (já sabemos que o valor que queremos é o de id 15)

# %%
payload = {"id": "15"} # só variar o id para obter os outros valores mobiliarios
url = "http://web.cvm.gov.br/app/esforcosrestritos/consultarOfertaController/getValorMobiliario"
response = requests.post(url=url,
                         json=payload,
                         headers=headers)
dict_response = json.loads(response.content)

# %%
dict_response
# Out:
# {'id': 15,
#  'dataInclusao': '2015-12-01T00:00:00Z',
#  'descricao': 'DEBÊNTURES SIMPLES',
#  'relacionadoFundoInvestimento': False,
#  'situacao': 'ATIVO'}

# %% [markdown]
# ## Primeiro, listamos as debentures desse ano usanda request abaixo:

# %%
payload = {
"ano": "2021",
"comunicado": "1",
"situacao": "1",
"situacaoAndamento": True,
"situacaoEncerrada": False,
"tipoComunicado": "INICIAL",
"valorMobiliarioId": "15",
}
url = "http://web.cvm.gov.br/app/esforcosrestritos/consultarOfertaController/consultarValorMobiliario"
response = requests.post(url=url, 
                     json=payload, 
                     headers=headers)
dict_response = json.loads(response.content)

# %%
dict_response[0] # exemplo de resposta
# Out:
# {'ofertasComunicadosTO': [{'ofertaTO': {'id': 17760,
#     'nomeResponsavel': 'TRAVESSIA SECURITIZADORA DE CRÉDITOS FINANCEIROS XVIII S.A.',
#     'dataInicio': '2021-01-11T00:00:00Z',
#     'numeroEmissao': 1,
#     'quantidadeSerie': 3,
#     'volumeOferta': '2.999.000,00',
#     'situacaoEncerrada': False,
#     'situacaoAndamento': False,
#     'tipoComunicado': 'PARCIAL'},
#    'comunicadosTO': [{'id': 38399,
#      'descricao': 'Formulário Inicial',
#      'dataInclusao': '2021-01-15T10:00:00Z',
#      'volume': '0,00',
#      'tipoComunicado': 'INICIAL'},
#     {'id': 46002,
#      'descricao': 'Formulário Parcial ',
#      'dataInclusao': '2021-07-08T15:33:00Z',
#      'volume': '2.999.000,00',
#      'tipoComunicado': 'PARCIAL'}]},
#   {'ofertaTO': {'id': 17758,
#     'nomeResponsavel': 'TRAVESSIA SECURITIZADORA DE CRÉDITOS FINANCEIROS XVIII S.A.',
#     'dataInicio': '2021-01-11T00:00:00Z',
#     'numeroEmissao': 1,
#     'quantidadeSerie': 1,
#     'volumeOferta': '0,00',
#     'situacaoEncerrada': False,
#     'situacaoAndamento': False,
#     'tipoComunicado': 'PARCIAL'},
#    'comunicadosTO': [{'id': 38397,
#      'descricao': 'Formulário Inicial',
#      'dataInclusao': '2021-01-15T09:53:00Z',
#      'volume': '0,00',
#      'tipoComunicado': 'INICIAL'},
#     {'id': 45998,
#      'descricao': 'Formulário Parcial ',
#      'dataInclusao': '2021-07-08T15:25:00Z',
#      'volume': '0,00',
#      'tipoComunicado': 'PARCIAL'}]},
#   {'ofertaTO': {'id': 17759,
#     'nomeResponsavel': 'TRAVESSIA SECURITIZADORA DE CRÉDITOS FINANCEIROS XVIII S.A.',
#     'dataInicio': '2021-01-11T00:00:00Z',
#     'numeroEmissao': 1,
#     'quantidadeSerie': 2,
#     'volumeOferta': '0,00',
#     'situacaoEncerrada': False,
#     'situacaoAndamento': False,
#     'tipoComunicado': 'PARCIAL'},
#    'comunicadosTO': [{'id': 38398,
#      'descricao': 'Formulário Inicial',
#      'dataInclusao': '2021-01-15T09:58:00Z',
#      'volume': '0,00',
#      'tipoComunicado': 'INICIAL'},
#     {'id': 45999,
#      'descricao': 'Formulário Parcial ',
#      'dataInclusao': '2021-07-08T15:26:00Z',
#      'volume': '0,00',
#      'tipoComunicado': 'PARCIAL'}]},
#   {'ofertaTO': {'id': 17813,
#     'nomeResponsavel': 'REVELO COMPANHIA SECURITIZADORA DE CREDITOS FINANCEIROS',
#     'dataInicio': '2021-01-18T00:00:00Z',
#     'numeroEmissao': 1,
#     'quantidadeSerie': 2,
#     'volumeOferta': '0,00',
#     'situacaoEncerrada': False,
#     'situacaoAndamento': False,
#     'tipoComunicado': 'INICIAL'},
#    'comunicadosTO': [{'id': 38521,
#      'descricao': 'Formulário Inicial',
#      'dataInclusao': '2021-01-19T19:53:00Z',
#      'volume': '0,00',
#      'tipoComunicado': 'INICIAL'}]},
#   {'ofertaTO': {'id': 17812,
#     'nomeResponsavel': 'REVELO COMPANHIA SECURITIZADORA DE CREDITOS FINANCEIROS',
#     'dataInicio': '2021-01-18T00:00:00Z',
#     'numeroEmissao': 1,
#     'quantidadeSerie': 1,
#     'volumeOferta': '0,00',
#     'situacaoEncerrada': False,
#     'situacaoAndamento': False,
#     'tipoComunicado': 'INICIAL'},
#    'comunicadosTO': [{'id': 38520,
#      'descricao': 'Formulário Inicial',
#      'dataInclusao': '2021-01-19T19:47:00Z',
#      'volume': '0,00',
#      'tipoComunicado': 'INICIAL'}]}],
#  'agrupador': 'Janeiro',
#  'totalVolume': '2.999.000,00'}

# %% [markdown]
# ## Agora podemos usar as infos obtidas na última request pra extrair mais dados

# %%
# 17760 é o id de uma das ofertas, mas podemos pegar esse id a partir da request acima
id_oferta = str(dict_response[0]['ofertasComunicadosTO'][0]['ofertaTO']['id']) # corresponde ao valor 17760 no caso do exemplo
url = "http://web.cvm.gov.br/app/esforcosrestritos/enviarFormularioParcial/getOfertaPorId/" + id_oferta
response = requests.get(url=url,
                         headers=headers)
dict_response = json.loads(response.content)
dict_response
# Out:
# {'id': 17760,
#  'dataInclusao': '2021-01-15T10:00:00Z',
#  'dataInicio': '2021-01-11T00:00:00Z',
#  'numeroEmissao': 1,
#  'quantidadeSerie': 3,
#  'valorMobiliario': {'id': 15,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'DEBÊNTURES SIMPLES',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  'tipoEspecie': {'id': 1, 'descricao': 'Garantia Real'},
#  'tipoClasse': {'id': 2, 'descricao': 'Subordinada'},
#  'tipoOferta': {'id': 1, 'descricao': 'Primária'},
#  'tipoForma': {'id': 3, 'descricao': 'Nominativa e Escritural'},
#  'ofertante': {'id': 35117,
#   'nomeResponsavel': 'TRAVESSIA SECURITIZADORA DE CRÉDITOS FINANCEIROS XVIII S.A.',
#   'cnpj': 38419803000158,
#   'paginaWeb': 'https://www.grupotravessia.com/',
#   'tipoSocietario': {'id': 5,
#    'descricao': 'Sociedade Anônima de Capital Fechado'}},
#  'emissor': {'id': 35116,
#   'nomeResponsavel': 'TRAVESSIA SECURITIZADORA DE CRÉDITOS FINANCEIROS XVIII S.A.',
#   'cnpj': 38419803000158,
#   'paginaWeb': 'https://www.grupotravessia.com/',
#   'tipoSocietario': {'id': 5,
#    'descricao': 'Sociedade Anônima de Capital Fechado'}},
#  'lider': {'id': 17357,
#   'nrPfPj': 3751794000113,
#   'dataRegistro': '2015-04-15T16:33:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25},
#  'instituicoesIntermediarias': [],
#  'valorPrecoUnitario': '1.000,00',
#  'inativo': False}

# %% [markdown]
# ## Achei algumas requests que não devo usar pra nada, mas vale documentar

# %% [markdown]
# ### Primeira

# %%
payload = {"quantidadeValorMobiliario": "2.999,0000", 
           "valorPrecoUnitario": "1.000,00"}
url = "http://web.cvm.gov.br/app/esforcosrestritos/oferta/calcularTotalOfertaCiasAbertasSecurizacao"
response = requests.post(url=url,
                         json=payload,
                         headers=headers)
dict_response = json.loads(response.content)

# %%
dict_response
# Out:
# '2.999.000,00'

# %% [markdown]
# ### Segunda

# %%
payload = {
	"colocacoes": [
		{
			"numeroInvestidores": 1,
			"quantidadeValorMobiliario": "333,0000",
			"tipoInvestidor": {
				"id": 1,
				"descricao": "Pessoas Físicas"
			}
		},
		{
			"tipoInvestidor": {
				"id": 2,
				"descricao": "Clubes de Investimento"
			}
		},
		{
			"numeroInvestidores": 4,
			"quantidadeValorMobiliario": "2.333,0000",
			"tipoInvestidor": {
				"id": 3,
				"descricao": "Fundos de Investimento"
			}
		},
		{
			"tipoInvestidor": {
				"id": 4,
				"descricao": "Entidades de previdência privada"
			}
		},
		{
			"tipoInvestidor": {
				"id": 5,
				"descricao": "Companhias seguradoras"
			}
		},
		{
			"tipoInvestidor": {
				"id": 6,
				"descricao": "Investidores estrangeiros"
			}
		},
		{
			"tipoInvestidor": {
				"id": 7,
				"descricao": "Instituições intermediárias participantes do consórcio de distribuição"
			}
		},
		{
			"tipoInvestidor": {
				"id": 8,
				"descricao": "Instituições financeiras ligadas à emissora e/ou aos participantes do consórcio"
			}
		},
		{
			"tipoInvestidor": {
				"id": 9,
				"descricao": "Demais instituições financeiras"
			}
		},
		{
			"tipoInvestidor": {
				"id": 10,
				"descricao": "Demais pessoas jurídicas ligadas à emissora e/ou aos participantes do consórcio"
			}
		},
		{
			"numeroInvestidores": 1,
			"quantidadeValorMobiliario": "333,0000",
			"tipoInvestidor": {
				"id": 11,
				"descricao": "Demais pessoas jurídicas"
			}
		},
		{
			"tipoInvestidor": {
				"id": 12,
				"descricao": "Sócios, administradores, empregados, propostos, e demais pessoas ligadas à emissora e/ou aos participantes do consórcio"
			}
		},
		{
			"outroComunicado": True
		}
	]
}

# %%
url = "http://web.cvm.gov.br/app/esforcosrestritos/colocacao/somarQuantidadeValorMobiliario"
response = requests.post(url=url,
                         json=payload,
                         headers=headers)
dict_response = json.loads(response.content)

# %%
dict_response
# Out:
# '2.999,0000'

# %% [markdown]
# ### Terceira

# %%
url = "http://web.cvm.gov.br/app/esforcosrestritos/comunicado/listarTipoCliente"
response = requests.get(url=url,
                         headers=headers)
dict_response = json.loads(response.content)
dict_response
# Out:
# [{'id': 1, 'descricao': 'Pessoas Físicas'},
#  {'id': 2, 'descricao': 'Pessoas Jurídicas'},
#  {'id': 3, 'descricao': 'Pessoa Jurídica ligada à Administração'},
#  {'id': 4, 'descricao': 'Demais pessoas jurídicas'},
#  {'id': 5, 'descricao': 'Investidores estrangeiros'},
#  {'id': 6,
#   'descricao': 'Sócios, administradores, empregados, propostos, e demais pessoas ligadas à emissora e/ou aos participantes do consórcio'}]

# %% [markdown]
# ### Quarta

# %%
url = "http://web.cvm.gov.br/app/esforcosrestritos/comunicado/listarTipoInvestidor"
response = requests.get(url=url,
                         headers=headers)
dict_response = json.loads(response.content)
dict_response
# Out:
# [{'id': 1, 'descricao': 'Pessoas Físicas'},
#  {'id': 2, 'descricao': 'Clubes de Investimento'},
#  {'id': 3, 'descricao': 'Fundos de Investimento'},
#  {'id': 4, 'descricao': 'Entidades de previdência privada'},
#  {'id': 5, 'descricao': 'Companhias seguradoras'},
#  {'id': 6, 'descricao': 'Investidores estrangeiros'},
#  {'id': 7,
#   'descricao': 'Instituições intermediárias participantes do consórcio de distribuição'},
#  {'id': 8,
#   'descricao': 'Instituições financeiras ligadas à emissora e/ou aos participantes do consórcio'},
#  {'id': 9, 'descricao': 'Demais instituições financeiras'},
#  {'id': 10,
#   'descricao': 'Demais pessoas jurídicas ligadas à emissora e/ou aos participantes do consórcio'},
#  {'id': 11, 'descricao': 'Demais pessoas jurídicas'},
#  {'id': 12,
#   'descricao': 'Sócios, administradores, empregados, propostos, e demais pessoas ligadas à emissora e/ou aos participantes do consórcio'}]

# %% [markdown]
# ### Quinta

# %%
url = "http://web.cvm.gov.br/app/esforcosrestritos/comunicado/listarTipoGarantia"
response = requests.get(url=url,
                         headers=headers)
dict_response = json.loads(response.content)
dict_response
# Out:
# [{'id': 1, 'descricao': 'Penhor'},
#  {'id': 2, 'descricao': 'Fidejussória'},
#  {'id': 3, 'descricao': 'Hipoteca'},
#  {'id': 4, 'descricao': 'Não Aplicável'},
#  {'id': 5, 'descricao': 'Outra'}]

# %% [markdown]
# ### Sexta

# %%
payload = {
	"id": 17760,
	"dataInclusao": "2021-01-15T10:00:00Z",
	"dataInicio": "2021-01-11T00:00:00Z",
	"numeroEmissao": 1,
	"quantidadeSerie": 3,
	"valorMobiliario": {
		"id": 15,
		"dataInclusao": "2015-12-01T00:00:00Z",
		"descricao": "DEBÊNTURES SIMPLES",
		"relacionadoFundoInvestimento": False,
		"situacao": "ATIVO"
	},
	"tipoEspecie": {
		"id": 1,
		"descricao": "Garantia Real"
	},
	"tipoClasse": {
		"id": 2,
		"descricao": "Subordinada"
	},
	"tipoOferta": {
		"id": 1,
		"descricao": "Primária"
	},
	"tipoForma": {
		"id": 3,
		"descricao": "Nominativa e Escritural"
	},
	"ofertante": {
		"id": 35117,
		"nomeResponsavel": "TRAVESSIA SECURITIZADORA DE CRÉDITOS FINANCEIROS XVIII S.A.",
		"cnpj": 38419803000158,
		"paginaWeb": "https://www.grupotravessia.com/",
		"tipoSocietario": {
			"id": 5,
			"descricao": "Sociedade Anônima de Capital Fechado"
		}
	},
	"emissor": {
		"id": 35116,
		"nomeResponsavel": "TRAVESSIA SECURITIZADORA DE CRÉDITOS FINANCEIROS XVIII S.A.",
		"cnpj": 38419803000158,
		"paginaWeb": "https://www.grupotravessia.com/",
		"tipoSocietario": {
			"id": 5,
			"descricao": "Sociedade Anônima de Capital Fechado"
		}
	},
	"lider": {
		"id": 17357,
		"nrPfPj": 3751794000113,
		"dataRegistro": "2015-04-15T16:33:00Z",
		"codigoTipoPessoa": "PJ",
		"codigoTipoParticipante": 25
	},
	"instituicoesIntermediarias": [],
	"valorPrecoUnitario": "1.000,00",
	"inativo": False,
	"qtdValoresMobiliarios": 0,
	"valorTotalOferta": 0,
	"variasSeries": True
}

# %%
url = "http://web.cvm.gov.br/app/esforcosrestritos/comunicado/getUltimoComunicado"
response = requests.post(url=url, 
                        json=payload,
                         headers=headers)
dict_response = json.loads(response.content)
dict_response
# Out:
# {'id': 46002,
#  'dataInclusao': '2021-07-08T15:33:00Z',
#  'quantidadeFundos': 2,
#  'tipoGarantia': {'id': 4, 'descricao': 'Não Aplicável'},
#  'tipoComunicado': 'PARCIAL',
#  'colocacoes': [{'id': 33919,
#    'numeroInvestidores': 1,
#    'quantidadeValorMobiliario': '333,0000',
#    'tipoInvestidor': {'id': 1, 'descricao': 'Pessoas Físicas'}},
#   {'id': 33921,
#    'numeroInvestidores': 1,
#    'quantidadeValorMobiliario': '333,0000',
#    'tipoInvestidor': {'id': 11, 'descricao': 'Demais pessoas jurídicas'}},
#   {'id': 33920,
#    'numeroInvestidores': 4,
#    'quantidadeValorMobiliario': '2.333,0000',
#    'tipoInvestidor': {'id': 3, 'descricao': 'Fundos de Investimento'}}],
#  'administradoresRecursos': [],
#  'inativo': False,
#  'variosGestoresFundo': False,
#  'variosAdministradoresRecursos': False,
#  'variosInvestidorNaoResidente': False}

# %% [markdown]
# ### Sétima

# %%
payload = {"cnpj": 3751794000113}
url = "http://web.cvm.gov.br/app/esforcosrestritos/responsavel/getNomeResponsavelPorCnpj"
response = requests.post(url=url,
                         json=payload,
                         headers=headers)
dict_response = json.loads(response.content)
dict_response
# Out:
# 'TERRA INVESTIMENTOS DISTRIBUIDORA DE TITULOS E VALORES MOBILIARIOS LTDA'

# %% [markdown]
# ### Oitavo

# %%
url = "http://web.cvm.gov.br/app/esforcosrestritos/oferta/listarValoresMobiliariosAtivos"
response = requests.get(url=url,
                         headers=headers)
dict_response = json.loads(response.content)
dict_response
# Out:
# [{'id': 1,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'AÇÕES ORDINÁRIAS',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 2,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'AÇÔES PREFERENCIAIS',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 3,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'BDR PATROCINADO NÍVEL III',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 4,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'BÔNUS DE SUBSCRIÇÃO',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 5,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'CÉDULAS DE CRÉDITO BANCÁRIO - CCB',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 6,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'CÉDULAS DE PRODUTO RURAL - FINANCEIRAS - CPR',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 7,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'CERTIFICADOS DE DEPÓSITO DE VALORES MOBILIÁRIOS',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 8,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'CERTIFICADOS DE DIREITOS CREDITÓRIOS DO AGRONEGÓCIO - CDCA',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 9,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'CERTIFICADOS DE OPERAÇÕES ESTRUTURADAS - COE',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 10,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'CERTIFICADOS DE RECEBÍVEIS DO AGRONEGÓCIO - CRA',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 11,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'CERTIFICADOS DE RECEBÍVEIS IMOBILIÁRIOS - CRI',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 12,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'CONTRATO DE INVESTIMENTO COLETIVO - CIC',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 13,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'DEBÊNTURES CONVERSÍVEIS',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 14,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'DEBÊNTURES PERMUTÁVEIS',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 15,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'DEBÊNTURES SIMPLES',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 16,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'LETRAS FINANCEIRAS',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 17,
#   'dataInclusao': '2015-12-01T00:00:00Z',
#   'descricao': 'NOTAS PROMISSÓRIAS',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 18,
#   'dataInclusao': '2015-12-02T00:00:00Z',
#   'descricao': 'COTAS DE FUNDOS DE INVESTIMENTO FECHADOS',
#   'relacionadoFundoInvestimento': True,
#   'situacao': 'ATIVO'},
#  {'id': 19,
#   'dataInclusao': '2015-12-02T00:00:00Z',
#   'descricao': 'WARRANTS AGROPECUÁRIOS',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'},
#  {'id': 20,
#   'dataInclusao': '2020-06-24T00:00:00Z',
#   'descricao': 'BDR PATROCINADO NÍVEL II',
#   'relacionadoFundoInvestimento': False,
#   'situacao': 'ATIVO'}]

# %% [markdown]
# ### Nona (na verdade, juntei várias parecidas)

# %%
lista_urls = ["http://web.cvm.gov.br/app/esforcosrestritos/oferta/listarFormas","http://web.cvm.gov.br/app/esforcosrestritos/oferta/listarClasses",
"http://web.cvm.gov.br/app/esforcosrestritos/oferta/listarEspecies","http://web.cvm.gov.br/app/esforcosrestritos/oferta/listarTiposOferta",
"http://web.cvm.gov.br/app/esforcosrestritos/responsavel/listarTiposSocietarios"]

for url in lista_urls:
	response = requests.get(url=url,
							headers=headers)
	dict_response = json.loads(response.content)
	print(dict_response)
# Out:
# [{'id': 1, 'descricao': 'Nominativa'}, {'id': 2, 'descricao': 'Escritural'}, {'id': 3, 'descricao': 'Nominativa e Escritural'}]
# [{'id': 1, 'descricao': 'Sênior'}, {'id': 2, 'descricao': 'Subordinada'}, {'id': 3, 'descricao': 'Subordinada Mezanino'}, {'id': 4, 'descricao': 'Não Aplicável'}]
# [{'id': 1, 'descricao': 'Garantia Real'}, {'id': 2, 'descricao': 'Garantia Flutuante'}, {'id': 3, 'descricao': 'Sem Preferência'}, {'id': 4, 'descricao': 'Subordinada'}, {'id': 5, 'descricao': 'Não Aplicável'}]
# [{'id': 1, 'descricao': 'Primária'}, {'id': 2, 'descricao': 'Secundária'}]
# [{'id': 1, 'descricao': 'Fundo de Investimento'}, {'id': 2, 'descricao': 'Cooperativa'}, {'id': 3, 'descricao': 'Pessoa Física'}, {'id': 4, 'descricao': 'Sociedade Anônima de Capital Aberto'}, {'id': 5, 'descricao': 'Sociedade Anônima de Capital Fechado'}]

# %% [markdown]
# ### Décima (essa parece importante)

# %%
url = "http://web.cvm.gov.br/app/esforcosrestritos/instituicao/listarInstituicoesIntermediarias"
response = requests.get(url=url,
                         headers=headers)
dict_response = json.loads(response.content)
dict_response
# Out:
# [{'nrPfPj': 55555555555,
#   'dataRegistro': '1900-01-01T15:11:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '-- SEM DIRETOR RESPONSÁVEL --'},
#  {'nrPfPj': 35098686000180,
#   'dataRegistro': '2020-08-11T09:59:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '10B GESTORA DE RECURSOS LTDA.'},
#  {'nrPfPj': 3772674000100,
#   'dataRegistro': '2002-02-28T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': '202 PARTICIPAÇÕES S/A'},
#  {'nrPfPj': 7063675000129,
#   'dataRegistro': '2005-07-15T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '2B CAPITAL S.A.'},
#  {'nrPfPj': 8773135000100,
#   'dataRegistro': '2020-10-29T17:43:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': '2W ENERGIA S.A.'},
#  {'nrPfPj': 17776271000136,
#   'dataRegistro': '2013-07-02T19:09:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '3G RADAR GESTORA DE RECURSOS LTDA'},
#  {'nrPfPj': 29063944000190,
#   'dataRegistro': '2018-07-27T14:39:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '3J GESTORA DE RECURSOS LTDA. - ME'},
#  {'nrPfPj': 13641353000112,
#   'dataRegistro': '2011-07-25T14:54:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '3R GESTORA DE RECURSOS LTDA'},
#  {'nrPfPj': 12091809000155,
#   'dataRegistro': '2020-11-09T19:40:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': '3R PETROLEUM OLÉO E GÁS S.A.'},
#  {'nrPfPj': 33202473000120,
#   'dataRegistro': '2019-11-04T17:36:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '4+ CAPITAL LTDA.'},
#  {'nrPfPj': 11402234000181,
#   'dataRegistro': '2010-06-10T12:33:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '4I CAPITAL LTDA                                                                                     '},
#  {'nrPfPj': 17817934000113,
#   'dataRegistro': '2014-01-23T17:24:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '4K INVESTIMENTOS LTDA'},
#  {'nrPfPj': 76621457000185,
#   'dataRegistro': '2006-10-05T14:31:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25,
#   'denominacaoSocial': '4UM DTVM S.A.'},
#  {'nrPfPj': 76621457000185,
#   'dataRegistro': '1995-08-04T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '4UM DTVM S.A.'},
#  {'nrPfPj': 3983856000112,
#   'dataRegistro': '2019-05-28T14:15:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': '4UM GESTÃO DE RECURSOS LTDA.                                                                        '},
#  {'nrPfPj': 1547749000116,
#   'dataRegistro': '1997-07-11T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': '521 PARTICIPAÇOES S.A. - EM LIQUIDAÇÃO EXTRAJUDICIAL'},
#  {'nrPfPj': 1851771000155,
#   'dataRegistro': '1997-05-30T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': '524 PARTICIPAÇOES SA'},
#  {'nrPfPj': 13935935000101,
#   'dataRegistro': '2012-03-16T16:11:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'A1 INVESTIMENTOS GESTAO DE RECURSOS LTDA'},
#  {'nrPfPj': 19225510000195,
#   'dataRegistro': '2017-04-24T16:03:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'A10 INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 10705874000106,
#   'dataRegistro': '2009-07-30T14:36:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'A3 PERFORMANCE GESTAO DE RECURSOS LTDA'},
#  {'nrPfPj': 7152171000185,
#   'dataRegistro': '2006-12-12T11:14:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'A5 GESTÃO DE INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 33817677000176,
#   'dataRegistro': '2002-10-14T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25,
#   'denominacaoSocial': 'ABC BRASIL DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS S.A.'},
#  {'nrPfPj': 11074363000198,
#   'dataRegistro': '2011-06-22T13:28:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ABERDEEN DO BRASIL GESTAO DE RECURSOS LTDA'},
#  {'nrPfPj': 3575208743,
#   'dataRegistro': '2009-12-24T16:47:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ABILIO SANTOS FERREIRA FILHO'},
#  {'nrPfPj': 64635333191,
#   'dataRegistro': '2019-03-26T15:33:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ABNER LIMA DE OLIVEIRA'},
#  {'nrPfPj': 97522536000109,
#   'dataRegistro': '2011-10-17T16:05:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ABRADINVEST GESTAO DE RECURSOS FINANCEIROS LTDA'},
#  {'nrPfPj': 3788716000193,
#   'dataRegistro': '2006-04-04T12:55:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ABRIL S/A'},
#  {'nrPfPj': 17285755000182,
#   'dataRegistro': '2013-03-19T16:54:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ABSOLUTE GESTAO DE INVESTIMENTOS LTDA'},
#  {'nrPfPj': 32541657000152,
#   'dataRegistro': '2019-07-12T10:58:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ABSOLUTO PARTNERS GESTÃO DE RECURSOS LTDA.'},
#  {'nrPfPj': 12147903000189,
#   'dataRegistro': '2014-04-16T17:24:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AC2 INVESTIMENTOS LTDA'},
#  {'nrPfPj': 33411393000185,
#   'dataRegistro': '2019-08-05T11:29:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ACE CAPITAL GESTORA DE RECURSOS LTDA.'},
#  {'nrPfPj': 43209436000106,
#   'dataRegistro': '2014-02-19T17:55:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ACECO TI S.A.'},
#  {'nrPfPj': 2126673000118,
#   'dataRegistro': '2001-02-06T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ACOM COMUNICAÇÕES S/A'},
#  {'nrPfPj': 7825881000129,
#   'dataRegistro': '2006-04-24T15:35:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ACRUX SECURITIZADORA S/A'},
#  {'nrPfPj': 38412222000194,
#   'dataRegistro': '2021-02-23T09:41:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ACTUM CAPITAL GESTÃO DE RECURSOS LTDA.                                                              '},
#  {'nrPfPj': 21778678000170,
#   'dataRegistro': '2020-09-01T16:20:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AÇU PETRÓLEO S.A.                                                                                   '},
#  {'nrPfPj': 18167777000100,
#   'dataRegistro': '2013-07-22T16:52:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ACURA GESTORA DE RECURSOS LTDA'},
#  {'nrPfPj': 17905206000163,
#   'dataRegistro': '2013-06-21T19:49:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADAMCAPITAL GESTÃO DE RECURSOS LTDA.                                                                '},
#  {'nrPfPj': 46898271768,
#   'dataRegistro': '2000-03-13T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADAUTO FRANCISCO SANTOS MADALENA'},
#  {'nrPfPj': 14208541865,
#   'dataRegistro': '2021-04-14T11:17:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADAUTO SOARES FERREIRA MARTINS'},
#  {'nrPfPj': 10930955714,
#   'dataRegistro': '2012-03-23T16:14:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADELMAR PINHEIRO SILVA JUNIOR'},
#  {'nrPfPj': 28990508851,
#   'dataRegistro': '2015-10-16T13:03:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADILSON AUGUSTO MARTINS JÚNIOR'},
#  {'nrPfPj': 1738445968,
#   'dataRegistro': '2015-11-12T10:10:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADMINISTRADOR JUDICIAL DA MASSA FALIDA DA CRUZEIRO DO SUL S.A. DTVM'},
#  {'nrPfPj': 10645051802,
#   'dataRegistro': '2017-05-31T13:54:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADMINISTRADOR JUDICIAL DA MASSA FALIDA DA CRUZEIRO DO SUL S.A. DTVM (LASPRO)'},
#  {'nrPfPj': 26630478304,
#   'dataRegistro': '2013-05-23T11:05:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADMINISTRADOR JUDICIAL DA MASSA FALIDA DA OBOÉ'},
#  {'nrPfPj': 4722005931,
#   'dataRegistro': '2019-11-25T13:28:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADONAY HERMES DEPINÉ DE FREITAS'},
#  {'nrPfPj': 33314211899,
#   'dataRegistro': '2017-06-28T12:39:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANA ELIAN JIMENEZ'},
#  {'nrPfPj': 16587951805,
#   'dataRegistro': '2015-09-24T14:06:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANA NEUMARK'},
#  {'nrPfPj': 22075983810,
#   'dataRegistro': '2014-06-24T16:52:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO BONI DE SOUZA'},
#  {'nrPfPj': 18024672898,
#   'dataRegistro': '2005-09-26T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO CARNEIRO PICCININ'},
#  {'nrPfPj': 1648054781,
#   'dataRegistro': '2009-09-21T12:02:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO CIVES SEABRA'},
#  {'nrPfPj': 54526779504,
#   'dataRegistro': '2009-01-13T12:32:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO FONTES ALVES DOS SANTOS'},
#  {'nrPfPj': 7692038767,
#   'dataRegistro': '2019-12-17T10:37:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO FREITAS BERNARDI'},
#  {'nrPfPj': 17530529803,
#   'dataRegistro': '2015-10-21T13:24:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO GENIS GHELMAN'},
#  {'nrPfPj': 1001468724,
#   'dataRegistro': '2013-05-07T10:40:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO JOSE NEGREIROS VAZ NETTO'},
#  {'nrPfPj': 24575216291,
#   'dataRegistro': '2010-05-11T14:44:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO LEITE SOARES'},
#  {'nrPfPj': 81153295687,
#   'dataRegistro': '2009-10-27T16:11:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO LIMA E SILVA'},
#  {'nrPfPj': 347843905,
#   'dataRegistro': '2007-05-23T11:55:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO PALADINO ALVES MARQUES DE SOUSA'},
#  {'nrPfPj': 24547371830,
#   'dataRegistro': '2019-05-31T11:27:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO PESCADA'},
#  {'nrPfPj': 65527410572,
#   'dataRegistro': '2012-07-20T16:46:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIANO ROQUE SOUZA SUZARTE'},
#  {'nrPfPj': 36843828841,
#   'dataRegistro': '2021-03-08T10:15:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ADRIEL MARTINS DE FREITAS BRANCO'},
#  {'nrPfPj': 10345009000198,
#   'dataRegistro': '2009-06-24T12:54:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ADVANCED DIGITAL HEALTH MEDICINA PREVENTIVA S.A.'},
#  {'nrPfPj': 4343254810,
#   'dataRegistro': '2014-05-20T14:48:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AECTO ANTONIO DE CAMPOS PINTO'},
#  {'nrPfPj': 8827501000158,
#   'dataRegistro': '2014-05-21T11:26:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AEGEA SANEAMENTO E PARTICIPAÇÕES S.A.'},
#  {'nrPfPj': 12528708000107,
#   'dataRegistro': '2020-11-09T18:41:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AERIS IND. E COM. DE EQUIP. PARA GER. DE ENG. S.A.'},
#  {'nrPfPj': 37663076000107,
#   'dataRegistro': '2021-03-18T13:12:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AES Brasil Energia S/A'},
#  {'nrPfPj': 194724000113,
#   'dataRegistro': '2021-05-13T08:57:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AES BRASIL OPERAÇÕES S.A.'},
#  {'nrPfPj': 4128563000110,
#   'dataRegistro': '2001-06-29T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AES TIETÊ ENERGIA S.A'},
#  {'nrPfPj': 3226533000184,
#   'dataRegistro': '2006-04-18T10:44:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AF INVEST ADMINISTRAÇÃO DE RECURSOS LTDA                                                            '},
#  {'nrPfPj': 21431855000147,
#   'dataRegistro': '2018-05-09T16:58:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ÁFIRA GESTÃO DE RECURSOS LTDA.'},
#  {'nrPfPj': 10338320000100,
#   'dataRegistro': '2010-09-24T10:10:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AFLUENTE TRANSMISSÃO DE ENERGIA ELETRICA S/A'},
#  {'nrPfPj': 15356418000,
#   'dataRegistro': '2008-11-19T12:57:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AFONSO ARNO ARNHOLD'},
#  {'nrPfPj': 62842820797,
#   'dataRegistro': '2007-09-11T12:06:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': "AFONSO SANT'ANNA BEVILAQUA"},
#  {'nrPfPj': 12807978000149,
#   'dataRegistro': '2012-06-21T14:41:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AGBI ATIVOS REAIS LTDA'},
#  {'nrPfPj': 8195535000177,
#   'dataRegistro': '2008-05-29T15:19:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AGGREGA INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 74014747000135,
#   'dataRegistro': '1993-12-22T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 20,
#   'denominacaoSocial': 'AGORA CTVM S.A.'},
#  {'nrPfPj': 7698047000110,
#   'dataRegistro': '2007-02-22T16:27:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AGRA EMPREENDIMENTOS IMOBILIÁRIOS S/A'},
#  {'nrPfPj': 21240146000184,
#   'dataRegistro': '2021-03-19T16:56:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AGROGALAXY PARTICIPAÇÕES S.A'},
#  {'nrPfPj': 27157474000106,
#   'dataRegistro': '2021-02-25T17:33:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ÁGUAS DE TERESINA SANEAMENTO SPE S.A.'},
#  {'nrPfPj': 27157474000106,
#   'dataRegistro': '2019-05-13T15:32:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ÁGUAS DE TERESINA SANEAMENTO SPE S.A.'},
#  {'nrPfPj': 4089570000150,
#   'dataRegistro': '2014-08-06T12:53:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AGUAS GUARIROBA S.A.'},
#  {'nrPfPj': 5946654000126,
#   'dataRegistro': '2003-11-24T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AGUILA CAPITAL ADMINISTRAÇÃO E GESTÃO DE CAPITAIS LTDA.                                             '},
#  {'nrPfPj': 96854294800,
#   'dataRegistro': '1998-05-29T09:39:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AGUINALDO ANTONIO A.DA FONSECA'},
#  {'nrPfPj': 9016372890,
#   'dataRegistro': '2020-08-25T10:17:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AGUINALDO BARBIERI'},
#  {'nrPfPj': 13189560000188,
#   'dataRegistro': '2011-07-25T14:36:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AI REAL ESTATE ADMINISTRADORA DE VALORES MOBILIARIOS LTDA'},
#  {'nrPfPj': 64702243853,
#   'dataRegistro': '2001-04-04T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AILTON ANTONIO CORREA LEITE'},
#  {'nrPfPj': 36568013000109,
#   'dataRegistro': '2021-05-19T08:59:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AIPLAN GESTORA DE RECURSOS LTDA.'},
#  {'nrPfPj': 10260219878,
#   'dataRegistro': '2020-10-08T10:50:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AKIHIKO SATO'},
#  {'nrPfPj': 65153502791,
#   'dataRegistro': '2002-08-06T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAIN ROBERT POUCHUCQ'},
#  {'nrPfPj': 10354190000107,
#   'dataRegistro': '2012-11-16T17:54:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAMOS ADMINISTRADORA DE RECURSOS LTDA'},
#  {'nrPfPj': 720618045,
#   'dataRegistro': '2016-02-03T10:44:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAN ANTONIO CORRÊA JR.'},
#  {'nrPfPj': 30435392816,
#   'dataRegistro': '2017-05-04T15:01:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAN GLEZER'},
#  {'nrPfPj': 1681799707,
#   'dataRegistro': '2015-02-12T10:32:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAN HAIDINGER RAMOS'},
#  {'nrPfPj': 10831700742,
#   'dataRegistro': '2013-06-05T19:40:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAN JEFERSON PEREIRA GARCIA DE ARRUDA CÂMARA'},
#  {'nrPfPj': 23001513837,
#   'dataRegistro': '2019-05-03T17:05:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAN NERY'},
#  {'nrPfPj': 15329188873,
#   'dataRegistro': '2012-11-16T16:45:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAN RIGONI DE ALMEIDA SOUZA'},
#  {'nrPfPj': 15089883000125,
#   'dataRegistro': '2013-03-07T13:38:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALAOF DO BRASIL ADMINISTRADORA DE VALORES MOBILIARIOS E CONSULTORIA LTDA'},
#  {'nrPfPj': 11752203000150,
#   'dataRegistro': '2010-07-28T11:51:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALASKA INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 4855548871,
#   'dataRegistro': '2008-05-08T11:27:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALBERTO COSTA SOUSA CAMOES'},
#  {'nrPfPj': 2885692880,
#   'dataRegistro': '2007-06-04T11:45:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALBERTO GAIDYS JUNIOR'},
#  {'nrPfPj': 15418443860,
#   'dataRegistro': '1994-12-26T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALBERTO GARCIA ROCHE'},
#  {'nrPfPj': 16422192827,
#   'dataRegistro': '2008-11-06T17:24:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALBERTO LUIS DE SOUZA ARAUJO'},
#  {'nrPfPj': 84360380704,
#   'dataRegistro': '2011-06-22T13:33:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALBERTO MONTEIRO DE QUEIROZ NETTO'},
#  {'nrPfPj': 75901480759,
#   'dataRegistro': '2003-11-11T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALBERTO RIBEIRO GUTH'},
#  {'nrPfPj': 13056344000164,
#   'dataRegistro': '2011-09-22T15:20:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALBION CAPITAL LTDA'},
#  {'nrPfPj': 24556596823,
#   'dataRegistro': '2010-07-30T12:57:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALCINDO COSTA CANTO NETO'},
#  {'nrPfPj': 50608053791,
#   'dataRegistro': '2008-10-13T16:21:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALDO RIBEIRO DE MORAES'},
#  {'nrPfPj': 23314594000100,
#   'dataRegistro': '2001-06-29T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALE COMBUSTIVEIS SA'},
#  {'nrPfPj': 32926027850,
#   'dataRegistro': '2013-06-18T16:44:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEJANDRO AUGUSTO SCHIUMA'},
#  {'nrPfPj': 6168158758,
#   'dataRegistro': '2012-01-24T15:27:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEJANDRO EDUARDO KERSMAN'},
#  {'nrPfPj': 5498898843,
#   'dataRegistro': '2011-07-29T13:52:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALENCAR RODRIGUES FERREIRA JUNIOR'},
#  {'nrPfPj': 14818000191,
#   'dataRegistro': '2011-03-28T11:41:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALENIR DE OLIVEIRA ROMANELLO'},
#  {'nrPfPj': 1180129750,
#   'dataRegistro': '2013-05-08T12:33:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALESSANDRA AUGUSTA DE LIMA GOMES DA SILVA SOUZA'},
#  {'nrPfPj': 36959538882,
#   'dataRegistro': '2021-04-09T08:23:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALESSANDRO CASSIANO CARVALHO NEVES TAGNIN'},
#  {'nrPfPj': 32579002871,
#   'dataRegistro': '2019-12-03T11:19:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALESSANDRO DEL DRAGO'},
#  {'nrPfPj': 51229978100,
#   'dataRegistro': '2001-07-09T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALESSANDRO GASPERIN BARRETO'},
#  {'nrPfPj': 20264320824,
#   'dataRegistro': '2018-01-09T12:12:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALESSANDRO MARTINI GEMIGNANI CORREIA'},
#  {'nrPfPj': 515326704,
#   'dataRegistro': '2004-08-11T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALESSANDRO MONTEIRO MORGADO HORTA'},
#  {'nrPfPj': 6272334818,
#   'dataRegistro': '2016-09-28T10:41:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALESSANDRO TOLEDO CRUZOLINI'},
#  {'nrPfPj': 2376841950,
#   'dataRegistro': '2004-12-15T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALESSANDRO TRAPP'},
#  {'nrPfPj': 592759792,
#   'dataRegistro': '2007-09-11T12:16:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDER AMERICO ABIDO SOARES DA SILVA'},
#  {'nrPfPj': 5713739767,
#   'dataRegistro': '2012-08-17T16:37:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRA CATHERINE DE HAAN'},
#  {'nrPfPj': 2805635744,
#   'dataRegistro': '2007-08-16T16:20:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE ABRAO MARTINS'},
#  {'nrPfPj': 90048148768,
#   'dataRegistro': '2013-05-07T11:33:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE AMARAL DE MOURA'},
#  {'nrPfPj': 11073353702,
#   'dataRegistro': '2019-10-17T10:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE AMITAY'},
#  {'nrPfPj': 88833259900,
#   'dataRegistro': '2014-07-11T11:12:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE AMORIM'},
#  {'nrPfPj': 9634030793,
#   'dataRegistro': '2012-07-10T18:25:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE ANTUNES MACIEL HALLOT'},
#  {'nrPfPj': 17417754856,
#   'dataRegistro': '2016-05-25T14:09:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE AUGUSTO VITORINO'},
#  {'nrPfPj': 83738738720,
#   'dataRegistro': '2002-01-10T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE BARBOSA MATTOS'},
#  {'nrPfPj': 28256219866,
#   'dataRegistro': '2011-07-18T13:18:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE BASTIANI CANCHERINI'},
#  {'nrPfPj': 9869262724,
#   'dataRegistro': '2017-07-18T17:03:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE BATISTA LUDOLF GOMES'},
#  {'nrPfPj': 14744024882,
#   'dataRegistro': '2012-07-09T16:21:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE BIN WAN SONG'},
#  {'nrPfPj': 2395850705,
#   'dataRegistro': '2018-03-01T10:28:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE BORENSZTEIN'},
#  {'nrPfPj': 4301198792,
#   'dataRegistro': '1999-03-16T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE BOURGEOIS'},
#  {'nrPfPj': 22599540810,
#   'dataRegistro': '2020-07-01T09:38:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE CAMPANELLI SPADA'},
#  {'nrPfPj': 11211934802,
#   'dataRegistro': '2018-07-10T14:03:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE CÉSAR FELÍCIO'},
#  {'nrPfPj': 27315074899,
#   'dataRegistro': '2015-09-22T12:50:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE CRAVEIRO DELGADO'},
#  {'nrPfPj': 42663989304,
#   'dataRegistro': '2016-12-23T14:43:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE DA FROTA MOURÃO'},
#  {'nrPfPj': 7398787782,
#   'dataRegistro': '2015-12-22T11:15:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE DALPIERO DE FREITAS'},
#  {'nrPfPj': 8452178794,
#   'dataRegistro': '2012-05-10T15:38:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE DE ALMEIDA CANALINI'},
#  {'nrPfPj': 2225973806,
#   'dataRegistro': '2010-07-23T12:24:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE DE LIMA GHIRGHI'},
#  {'nrPfPj': 15219559800,
#   'dataRegistro': '2006-04-04T11:01:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE DE LUCCHI CARNEIRO'},
#  {'nrPfPj': 10084684798,
#   'dataRegistro': '2015-06-09T16:49:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE DE OLIVEIRA MULLER'},
#  {'nrPfPj': 26501108802,
#   'dataRegistro': '2006-12-20T17:47:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE DO ROSARIO NOBRE'},
#  {'nrPfPj': 2146447745,
#   'dataRegistro': '2001-11-07T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE FERNANDES E SOUZA'},
#  {'nrPfPj': 26755303879,
#   'dataRegistro': '2019-07-19T10:24:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE FERREIRA BOSSI'},
#  {'nrPfPj': 24686264863,
#   'dataRegistro': '2013-05-07T11:49:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE FILIZOLA'},
#  {'nrPfPj': 60008016704,
#   'dataRegistro': '2002-01-10T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE FOGLIANO DA CUNHA'},
#  {'nrPfPj': 31875151850,
#   'dataRegistro': '2014-01-29T17:57:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE FONTES TAMIETTO GALHANO'},
#  {'nrPfPj': 5354514827,
#   'dataRegistro': '2005-03-22T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE GALVAO'},
#  {'nrPfPj': 10466176805,
#   'dataRegistro': '2018-03-01T11:41:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE GOMIDE MOREIRA SANTOS'},
#  {'nrPfPj': 2475565721,
#   'dataRegistro': '2004-09-13T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE GORBERG'},
#  {'nrPfPj': 74349864768,
#   'dataRegistro': '2010-12-20T10:04:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE GRAEVER'},
#  {'nrPfPj': 15763651820,
#   'dataRegistro': '2006-05-17T11:04:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE GRZYBOWSKI'},
#  {'nrPfPj': 36836023841,
#   'dataRegistro': '2014-01-27T17:34:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE GUILGER DESPONTIN'},
#  {'nrPfPj': 2845063709,
#   'dataRegistro': '2004-09-08T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE HORSTMANN'},
#  {'nrPfPj': 25159704,
#   'dataRegistro': '2017-02-15T14:50:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE JADALLAH AOUDE'},
#  {'nrPfPj': 95452907734,
#   'dataRegistro': '2009-09-30T14:51:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE JEREISSATI LEGEY'},
#  {'nrPfPj': 86824040797,
#   'dataRegistro': '2008-02-13T14:56:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE JORGE CHAIA'},
#  {'nrPfPj': 10715547437,
#   'dataRegistro': '2019-01-10T15:01:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE JORGE DE MATTOS BRITO JUNIOR'},
#  {'nrPfPj': 92540295053,
#   'dataRegistro': '2020-03-12T14:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE KAERCHER'},
#  {'nrPfPj': 22194414827,
#   'dataRegistro': '2020-11-18T10:09:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE KENICHI ONO'},
#  {'nrPfPj': 45367620604,
#   'dataRegistro': '1993-03-11T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE KOCH TORRES DE ASSIS'},
#  {'nrPfPj': 12593187883,
#   'dataRegistro': '2015-10-16T13:16:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE KORTING DE ATAÍDE'},
#  {'nrPfPj': 7692273766,
#   'dataRegistro': '2013-03-20T18:21:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE LODI DE OLIVEIRA'},
#  {'nrPfPj': 8778093724,
#   'dataRegistro': '2007-10-05T17:28:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE LOURES DE ARAUJO PENNA'},
#  {'nrPfPj': 8132221761,
#   'dataRegistro': '2018-03-01T11:55:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE LOWENKRON'},
#  {'nrPfPj': 1772758981,
#   'dataRegistro': '2021-01-11T10:26:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE LUIZ ZIMATH'},
#  {'nrPfPj': 7630925760,
#   'dataRegistro': '2016-06-17T13:39:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE MARINHO GAUDIO'},
#  {'nrPfPj': 1266628789,
#   'dataRegistro': '2013-07-18T15:08:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE MATHEWS STURM COUTINHO'},
#  {'nrPfPj': 62450816615,
#   'dataRegistro': '2019-12-16T11:24:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE MENDES RIBEIRO MOREIRA'},
#  {'nrPfPj': 77670787600,
#   'dataRegistro': '2009-06-15T10:22:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE MOREIRA GALVAO'},
#  {'nrPfPj': 17621900873,
#   'dataRegistro': '2009-12-14T15:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE NEVES FERREIRA'},
#  {'nrPfPj': 60599421134,
#   'dataRegistro': '2008-05-08T10:20:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE PAIXAO SILVERIO'},
#  {'nrPfPj': 92852106787,
#   'dataRegistro': '2004-03-15T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE PAVAN POVOA'},
#  {'nrPfPj': 17643095884,
#   'dataRegistro': '2021-04-30T11:20:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE PEREIRA RODRIGUES DE SÁ CASTANHEIRA'},
#  {'nrPfPj': 99679523004,
#   'dataRegistro': '2020-02-05T11:15:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE PETEFFI'},
#  {'nrPfPj': 85325759787,
#   'dataRegistro': '2013-02-04T16:28:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE PIAU CAMARA'},
#  {'nrPfPj': 83120777153,
#   'dataRegistro': '2009-03-04T17:39:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE QUEIROZ VIVACQUA'},
#  {'nrPfPj': 29376108892,
#   'dataRegistro': '2018-07-16T10:29:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE REITZ AMARAL'},
#  {'nrPfPj': 15255855847,
#   'dataRegistro': '2012-06-21T14:27:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE RHINOW'},
#  {'nrPfPj': 89268032791,
#   'dataRegistro': '2014-09-05T10:11:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE ROBERTO RENTERÍA'},
#  {'nrPfPj': 24736298898,
#   'dataRegistro': '2010-05-13T13:49:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE SALFATIS'},
#  {'nrPfPj': 39751545862,
#   'dataRegistro': '2020-11-17T09:52:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE SANCHES EL SAHLI'},
#  {'nrPfPj': 58136843104,
#   'dataRegistro': '2015-03-03T11:06:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE SILVEIRA'},
#  {'nrPfPj': 15855841855,
#   'dataRegistro': '2020-01-14T09:35:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE SILVEIRA DIAS'},
#  {'nrPfPj': 4296219731,
#   'dataRegistro': '2013-07-18T15:15:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE SODERO REZENDE'},
#  {'nrPfPj': 31270029800,
#   'dataRegistro': '2020-09-08T09:30:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE SUMARIVA'},
#  {'nrPfPj': 19108045844,
#   'dataRegistro': '2010-09-06T16:45:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE TEIXEIRA DAMASCENO'},
#  {'nrPfPj': 11683417879,
#   'dataRegistro': '1997-07-30T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE TEIXEIRA DE ASSUMPCAO SAIGH'},
#  {'nrPfPj': 34277868894,
#   'dataRegistro': '2015-06-03T11:51:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE THIEDE DONINI'},
#  {'nrPfPj': 78557542020,
#   'dataRegistro': '2003-08-26T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE TORRANO DA CUNHA'},
#  {'nrPfPj': 19889281848,
#   'dataRegistro': '2010-12-03T14:45:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE VAZ GUIMARAES'},
#  {'nrPfPj': 45906564500,
#   'dataRegistro': '2020-07-03T10:46:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE XAVIER YWATA DE CARVALHO'},
#  {'nrPfPj': 25337717839,
#   'dataRegistro': '2012-01-24T14:58:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE YOCHIHITO SABANAI'},
#  {'nrPfPj': 89675886820,
#   'dataRegistro': '1997-01-07T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXANDRE ZAKIA ALBERT'},
#  {'nrPfPj': 12850201707,
#   'dataRegistro': '2020-07-01T09:16:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXIA DALCANALE BERGALLO'},
#  {'nrPfPj': 79657281172,
#   'dataRegistro': '2019-10-08T13:37:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALEXSANDRA CAMELO BRAGA'},
#  {'nrPfPj': 62178421000164,
#   'dataRegistro': '1968-07-15T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 20,
#   'denominacaoSocial': 'ALFA CCVM S.A.'},
#  {'nrPfPj': 17167396000169,
#   'dataRegistro': '1977-07-20T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALFA HOLDINGS SA'},
#  {'nrPfPj': 43107325000180,
#   'dataRegistro': '2000-06-08T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALFALEVY ADMINISTRACAO DE INVESTIMENTOS LTDA                                                        '},
#  {'nrPfPj': 3462325892,
#   'dataRegistro': '2005-08-01T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALFREDO ALTHEN SCHIAVO'},
#  {'nrPfPj': 3795800803,
#   'dataRegistro': '2015-11-27T11:59:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALFREDO ANTONIO LIMA DE MENEZES'},
#  {'nrPfPj': 1441421807,
#   'dataRegistro': '1989-07-06T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALFREDO EGYDIO SETUBAL'},
#  {'nrPfPj': 27090845893,
#   'dataRegistro': '2013-11-12T11:16:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALFREDO GONÇALVES CUNHA'},
#  {'nrPfPj': 2217911910,
#   'dataRegistro': '2021-05-18T09:42:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALFREDO KHOURI JÚNIOR'},
#  {'nrPfPj': 71208516000174,
#   'dataRegistro': '2007-07-27T17:28:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALGAR TELECOM S/A'},
#  {'nrPfPj': 38481640000133,
#   'dataRegistro': '2021-06-23T10:40:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALGARVE CAPITAL GESTÃO DE RECURSOS LTDA.'},
#  {'nrPfPj': 15437865000197,
#   'dataRegistro': '2012-07-09T17:18:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALGARVE GESTAO DE INVESTIMENTOS LTDA'},
#  {'nrPfPj': 5878397000132,
#   'dataRegistro': '2010-03-03T15:02:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALIANSCE SONAE SHOPPING CENTERS S.A.'},
#  {'nrPfPj': 5878397000132,
#   'dataRegistro': '2011-02-01T13:20:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALIANSCE SONAE SHOPPING CENTERS S.A.'},
#  {'nrPfPj': 21950366000100,
#   'dataRegistro': '2015-10-01T13:43:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALIANZA GESTÃO DE RECURSOS LTDA'},
#  {'nrPfPj': 1679319701,
#   'dataRegistro': '2013-09-13T14:48:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALINE LEITE SAN LEE SUN CAMARGO'},
#  {'nrPfPj': 58476180187,
#   'dataRegistro': '2010-12-29T10:35:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALISSON SAVIO SILVA SIQUEIRA'},
#  {'nrPfPj': 7191304766,
#   'dataRegistro': '2016-09-28T11:32:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALLAN HADID'},
#  {'nrPfPj': 3687117000183,
#   'dataRegistro': '2015-04-14T13:27:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALLIANCEBERNSTEIN ADMINISTRADORA DE CARTEIRAS (BRASIL) LTDA'},
#  {'nrPfPj': 20247322000147,
#   'dataRegistro': '2020-11-25T12:02:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALLIED TECNOLOGIA S.A.'},
#  {'nrPfPj': 60537263000166,
#   'dataRegistro': '2020-05-13T14:37:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALLPARK EMPREENDIMENTOS, PARTICIPAÇÕES E SERVIÇOS S.A.'},
#  {'nrPfPj': 82120676000183,
#   'dataRegistro': '2020-02-17T17:58:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALMEIDA JUNIOR SHOPPING CENTERS S.A.'},
#  {'nrPfPj': 82120676000183,
#   'dataRegistro': '2021-06-23T11:19:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALMEIDA JUNIOR SHOPPING CENTERS S.A.'},
#  {'nrPfPj': 8228243000193,
#   'dataRegistro': '2011-12-23T13:22:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALOCC GESTÃO FINANCEIRA LTDA.                                                                       '},
#  {'nrPfPj': 61079117000105,
#   'dataRegistro': '1977-07-20T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALPARGATAS SA'},
#  {'nrPfPj': 11721921000160,
#   'dataRegistro': '2010-10-28T18:18:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALPER CONSULTORIA E CORRETORA DE SEGUROS S.A.'},
#  {'nrPfPj': 15575770000130,
#   'dataRegistro': '2012-11-16T15:39:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALPHA CAPITAL PARTNERS GESTAO DE INVESTIMENTOS S.A                                                  '},
#  {'nrPfPj': 31340246000136,
#   'dataRegistro': '2019-04-12T10:13:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALPHA KEY CAPITAL MANAGEMENT INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 11000859000117,
#   'dataRegistro': '2009-10-08T12:32:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALPHA-MAR INVESTIMENTOS LTDA                                                                        '},
#  {'nrPfPj': 16811931000100,
#   'dataRegistro': '2020-11-05T12:23:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALPHAVILLE S.A.'},
#  {'nrPfPj': 446918000169,
#   'dataRegistro': '2013-03-27T15:01:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALPHAVILLE URBANISMO S.A.'},
#  {'nrPfPj': 446918000169,
#   'dataRegistro': '2020-03-03T17:37:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALPHAVILLE URBANISMO S.A.'},
#  {'nrPfPj': 28058342000181,
#   'dataRegistro': '2020-05-08T09:14:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALTA CAPITAL ADMINISTRAÇÃO DE FUNDOS E INVESTIMENTO ESTRATÉGICOS EIRELI'},
#  {'nrPfPj': 11683111877,
#   'dataRegistro': '2011-10-04T13:36:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALTAMIR BATISTA MATEUS DA SILVA'},
#  {'nrPfPj': 2783423000150,
#   'dataRegistro': '1998-12-10T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALTERE SECURITIZADORA S.A.'},
#  {'nrPfPj': 5704247717,
#   'dataRegistro': '2013-10-10T11:20:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALUIZIO HONORIO MOIZINHO JUNIOR'},
#  {'nrPfPj': 38411697000166,
#   'dataRegistro': '2021-02-23T09:24:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALUMMINI GESTÃO DE RECURSOS LTDA.'},
#  {'nrPfPj': 8364948000138,
#   'dataRegistro': '2008-06-18T11:49:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALUPAR INVESTIMENTO S/A'},
#  {'nrPfPj': 42233757000175,
#   'dataRegistro': '2021-07-06T11:04:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'ALVAREZ & MARSAL INVESTIMENTOS I S.A.'},
#  {'nrPfPj': 19739959806,
#   'dataRegistro': '2016-02-10T14:51:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALVARO AUGUSTO MARANGONI'},
#  {'nrPfPj': 57971463804,
#   'dataRegistro': '2005-05-13T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALVARO AVELINO CARVALHO DOS SANTOS'},
#  {'nrPfPj': 32663860867,
#   'dataRegistro': '2020-10-26T08:53:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALVARO CUNHA MATOS LESSA DE OLIVEIRA'},
#  {'nrPfPj': 78691044772,
#   'dataRegistro': '1999-02-08T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALVARO JOSE GALLIEZ NOVIS'},
#  {'nrPfPj': 6603414848,
#   'dataRegistro': '1997-09-01T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALVARO LUIS GONCALVES'},
#  {'nrPfPj': 81868758753,
#   'dataRegistro': '2011-11-22T10:27:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ALVARO LUIZ LISBOA BARATA SOARES'},
#  {'nrPfPj': 26440635824,
#   'dataRegistro': '2014-07-25T11:09:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ÁLVARO SCHOCAIR DE SOUZA FILHO'},
#  {'nrPfPj': 26760824000153,
#   'dataRegistro': '2017-05-23T11:48:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'ÂMAGO GESTÃO DE INVESTIMENTOS LTDA                                                                  '},
#  {'nrPfPj': 12790796653,
#   'dataRegistro': '1993-04-22T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AMARIL FRANKLIN'},
#  {'nrPfPj': 17312661000155,
#   'dataRegistro': '1967-08-25T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 20,
#   'denominacaoSocial': 'AMARIL FRANKLIN CTV LTDA'},
#  {'nrPfPj': 29535395653,
#   'dataRegistro': '2005-07-07T00:00:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AMAURY FONSECA JUNIOR'},
#  {'nrPfPj': 1310229899,
#   'dataRegistro': '2009-08-18T17:06:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AMAURY GUILHERME BIER'},
#  {'nrPfPj': 38543489000110,
#   'dataRegistro': '2021-04-09T09:17:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AMAZONE FUN PARKS S/A'},
#  {'nrPfPj': 38543489000110,
#   'dataRegistro': '2020-12-14T14:58:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AMAZONE FUN PARKS S/A'},
#  {'nrPfPj': 17889040000139,
#   'dataRegistro': '2013-08-13T17:01:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AMAZONIA INVESTIMENTOS LTDA'},
#  {'nrPfPj': 9012558000161,
#   'dataRegistro': '2014-09-12T11:11:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AMB CONSULTORES ASSOCIADOS LTDA.'},
#  {'nrPfPj': 7526557000100,
#   'dataRegistro': '2013-10-30T16:20:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AMBEV S.A.'},
#  {'nrPfPj': 12648266000124,
#   'dataRegistro': '2020-05-15T16:51:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AMBIPAR PARTICIPAÇÕES E EMPREENDIMENTOS S.A.'},
#  {'nrPfPj': 776574000156,
#   'dataRegistro': '2007-07-26T15:24:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AMERICANAS S.A.'},
#  {'nrPfPj': 15736867869,
#   'dataRegistro': '2013-02-15T16:45:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'AMERSON GALHARDO MAGALHAES'},
#  {'nrPfPj': 33050071000158,
#   'dataRegistro': '1969-08-15T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'AMPLA ENERGIA E SERVIÇOS S.A.'},
#  {'nrPfPj': 2835612000120,
# ...
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'BSI CAPITAL SECURITIZADORA S.A.'},
#  {'nrPfPj': 11257352000143,
#   'dataRegistro': '2012-12-14T18:29:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'BSI CAPITAL SECURITIZADORA S.A.'},
#  {'nrPfPj': 11257352000143,
#   'dataRegistro': '2013-04-17T16:56:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'BSI CAPITAL SECURITIZADORA S.A.'},
#  {'nrPfPj': 29650082000100,
#   'dataRegistro': '1986-12-17T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25,
#   'denominacaoSocial': 'BTG PACTUAL ASSET MANAGEMENT S/A DTVM'},
#  {'nrPfPj': 29650082000100,
#   'dataRegistro': '2000-05-10T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BTG PACTUAL ASSET MANAGEMENT S/A DTVM'},
#  {'nrPfPj': 43815158000122,
#   'dataRegistro': '2002-10-01T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 20,
#   'denominacaoSocial': 'BTG PACTUAL CTVM S/A'},
#  {'nrPfPj': 7625159000140,
#   'dataRegistro': '2006-03-31T15:57:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BTG PACTUAL GESTORA DE INVESTIMENTOS ALTERNATIVOS LTDA.                                             '},
#  {'nrPfPj': 9631542000137,
#   'dataRegistro': '2008-08-04T17:10:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BTG PACTUAL GESTORA DE RECURSOS LTDA'},
#  {'nrPfPj': 59281253000123,
#   'dataRegistro': '2005-03-17T15:21:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25,
#   'denominacaoSocial': 'BTG PACTUAL SERVIÇOS FINANCEIROS S/A DTVM'},
#  {'nrPfPj': 59281253000123,
#   'dataRegistro': '2006-03-20T11:50:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BTG PACTUAL SERVIÇOS FINANCEIROS S/A DTVM'},
#  {'nrPfPj': 60451242000123,
#   'dataRegistro': '2002-12-12T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BTG PACTUAL WM GESTÃO DE RECURSOS LTDA'},
#  {'nrPfPj': 21948105000147,
#   'dataRegistro': '2016-02-19T15:35:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'BTGI QUARTZO PARTICIPAÇÕES S.A.'},
#  {'nrPfPj': 21976510000179,
#   'dataRegistro': '2016-02-19T15:17:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'BTGI SAFIRA PARTICIPAÇÕES S.A.'},
#  {'nrPfPj': 26122817000126,
#   'dataRegistro': '2017-03-13T14:05:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BTO GESTÃO DE RECURSOS LTDA'},
#  {'nrPfPj': 86047198000184,
#   'dataRegistro': '2005-04-12T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'BUDDEMEYER S/A'},
#  {'nrPfPj': 49972326000170,
#   'dataRegistro': '2018-05-15T12:20:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'BUNGE AÇÚCAR E BIOENERGIA S.A.'},
#  {'nrPfPj': 22899452000190,
#   'dataRegistro': '2015-09-30T13:37:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BUTIÁ GESTÃO DE INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 4794781000194,
#   'dataRegistro': '2003-09-15T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'BVA EMPREENDIMENTOS SA'},
#  {'nrPfPj': 3214650000128,
#   'dataRegistro': '2008-05-19T17:13:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BW GESTÃO DE INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 17489133000176,
#   'dataRegistro': '2013-10-24T12:20:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'BWAG GESTÃO DE RECURSOS LTDA'},
#  {'nrPfPj': 45242914000105,
#   'dataRegistro': '2019-10-24T14:56:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'C&A MODAS S.A.'},
#  {'nrPfPj': 62274857000157,
#   'dataRegistro': '1968-07-29T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25,
#   'denominacaoSocial': 'C.R. 500 DTVM LTDA'},
#  {'nrPfPj': 32345784000186,
#   'dataRegistro': '2019-02-18T11:31:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 20,
#   'denominacaoSocial': 'C6 CORRETORA DE TÍTULOS E VALORES MOBILIÁRIOS LTDA.'},
#  {'nrPfPj': 1638542000157,
#   'dataRegistro': '2001-09-04T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25,
#   'denominacaoSocial': 'CA INDOSUEZ WEALTH (BRAZIL) S.A. DTVM'},
#  {'nrPfPj': 1638542000157,
#   'dataRegistro': '1999-11-18T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CA INDOSUEZ WEALTH (BRAZIL) S.A. DTVM'},
#  {'nrPfPj': 4030182000102,
#   'dataRegistro': '2001-10-29T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CABINDA PARTICIPAÇÕES SA'},
#  {'nrPfPj': 5336882000184,
#   'dataRegistro': '2011-12-19T15:52:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CACHOEIRA PAULISTA TRANSMISSORA DE ENERGIA SA'},
#  {'nrPfPj': 4031213000131,
#   'dataRegistro': '2001-10-29T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CACONDE PARTICIPAÇÕES SA'},
#  {'nrPfPj': 19037127000103,
#   'dataRegistro': '2014-01-13T14:12:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CADENCE GESTORA DE RECURSOS LTDA'},
#  {'nrPfPj': 4038763000182,
#   'dataRegistro': '2001-10-29T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CAIANDA PARTICIPAÇÕES SA'},
#  {'nrPfPj': 99221870600,
#   'dataRegistro': '2021-05-13T08:34:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIMI FRANCO REIS'},
#  {'nrPfPj': 10336512651,
#   'dataRegistro': '2017-06-28T11:52:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO BIZINOTO FRANCO'},
#  {'nrPfPj': 22343135894,
#   'dataRegistro': '2013-12-09T16:23:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO BORIA DE OLIVEIRA'},
#  {'nrPfPj': 34826233841,
#   'dataRegistro': '2020-05-13T11:53:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO DE SOUZA CONCA'},
#  {'nrPfPj': 11113912707,
#   'dataRegistro': '2012-09-21T15:23:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO FERNANDES NEVES'},
#  {'nrPfPj': 27876570879,
#   'dataRegistro': '2015-10-16T12:53:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO FROHLICH MERCADANTE'},
#  {'nrPfPj': 4305969793,
#   'dataRegistro': '2008-10-13T16:33:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO LEAL COSTA'},
#  {'nrPfPj': 35743973806,
#   'dataRegistro': '2019-12-17T10:21:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO LEWKOWICZ'},
#  {'nrPfPj': 4872211170,
#   'dataRegistro': '2020-10-26T09:32:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO VINICIUS FERNANDES'},
#  {'nrPfPj': 25899990899,
#   'dataRegistro': '2015-09-18T10:49:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIO WEIL VILLARES'},
#  {'nrPfPj': 979969000156,
#   'dataRegistro': '1996-09-04T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CAIXA ADM DIV PUB ESTADUAL SA'},
#  {'nrPfPj': 360305000104,
#   'dataRegistro': '2002-11-05T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 18,
#   'denominacaoSocial': 'CAIXA ECONOMICA FEDERAL'},
#  {'nrPfPj': 360305000104,
#   'dataRegistro': '1995-01-04T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAIXA ECONOMICA FEDERAL'},
#  {'nrPfPj': 22543331000100,
#   'dataRegistro': '2015-12-17T16:52:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CAIXA SEGURIDADE PARTICIPAÇÕES S.A.'},
#  {'nrPfPj': 61088894000108,
#   'dataRegistro': '1985-01-05T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CAMBUCI SA'},
#  {'nrPfPj': 14127491000140,
#   'dataRegistro': '2012-06-06T16:35:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAMBUHY INVESTIMENTOS LTDA'},
#  {'nrPfPj': 64904295000103,
#   'dataRegistro': '2011-02-07T09:52:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CAMIL ALIMENTOS S/A'},
#  {'nrPfPj': 64904295000103,
#   'dataRegistro': '2017-09-26T15:36:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CAMIL ALIMENTOS S/A'},
#  {'nrPfPj': 6824742902,
#   'dataRegistro': '2020-09-10T09:34:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAMILA DE PAULA XAVIER DE ALMEIDA'},
#  {'nrPfPj': 8440400705,
#   'dataRegistro': '2018-07-30T10:22:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAMILA ROSA GÓES'},
#  {'nrPfPj': 32246290880,
#   'dataRegistro': '2019-02-13T10:54:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAMILO DE LELLIS CAVALCANTI JUNIOR'},
#  {'nrPfPj': 97814571049,
#   'dataRegistro': '2015-06-26T11:39:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAMILO MARCANTONIO JUNIOR'},
#  {'nrPfPj': 97552976000109,
#   'dataRegistro': '2020-02-10T12:44:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CANOPUS HOLDING S.A.'},
#  {'nrPfPj': 15377863000150,
#   'dataRegistro': '2012-09-06T16:37:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CANVAS CAPITAL S.A.'},
#  {'nrPfPj': 11646992000145,
#   'dataRegistro': '2011-01-06T10:26:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAPITAL GESTÃO E INVESTIMENTOS LTDA'},
#  {'nrPfPj': 15229110000105,
#   'dataRegistro': '2014-03-07T12:39:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CAPITALE SECURITIZADORA DE CREDITO S.A.'},
#  {'nrPfPj': 2591787000139,
#   'dataRegistro': '1998-07-09T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CAPITALPART PARTICIPAÇÕES SA'},
#  {'nrPfPj': 62063813000188,
#   'dataRegistro': '1989-06-22T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25,
#   'denominacaoSocial': 'CAPITANEA DTVM'},
#  {'nrPfPj': 4274010000176,
#   'dataRegistro': '2003-06-03T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAPITANIA S/A'},
#  {'nrPfPj': 29580517000189,
#   'dataRegistro': '2019-02-18T10:58:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAPRI INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 33552500000195,
#   'dataRegistro': '2019-12-20T10:39:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAPSTONE PARTNERS GESTÃO DE RECURSOS LTDA.'},
#  {'nrPfPj': 36012644000147,
#   'dataRegistro': '2020-10-08T10:05:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAPSUR CAPITAL GESTÃO DE RECURSOS LTDA.'},
#  {'nrPfPj': 36266751000100,
#   'dataRegistro': '2020-11-10T15:32:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 25,
#   'denominacaoSocial': 'CAPTALYS DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS LTDA.'},
#  {'nrPfPj': 36266751000100,
#   'dataRegistro': '2021-03-15T10:03:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAPTALYS DISTRIBUIDORA DE TÍTULOS E VALORES MOBILIÁRIOS LTDA.'},
#  {'nrPfPj': 13703306000156,
#   'dataRegistro': '2011-08-04T12:29:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CAPTALYS GESTÃO LTDA.                                                                               '},
#  {'nrPfPj': 80671000100,
#   'dataRegistro': '2021-06-17T10:39:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CARAMURU ALIMENTOS S.A.'},
#  {'nrPfPj': 34530561000114,
#   'dataRegistro': '2020-12-14T10:40:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARAVELA CONSULTORIA E GESTÃO DE INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 7253321000147,
#   'dataRegistro': '1993-07-27T00:00:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 1,
#   'denominacaoSocial': 'CARBOMIL SA MINER. E INDUSTRIA'},
#  {'nrPfPj': 38265784000152,
#   'dataRegistro': '2020-12-08T10:42:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARBON ASSET MANAGEMENT LTDA.'},
#  {'nrPfPj': 38318963000100,
#   'dataRegistro': '2021-06-11T09:11:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARBYNE GESTÃO DE RECURSOS LTDA.'},
#  {'nrPfPj': 23089950000130,
#   'dataRegistro': '2015-12-28T13:11:00Z',
#   'codigoTipoPessoa': 'PJ',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARDINAL PARTNERS INVESTIMENTOS LTDA.'},
#  {'nrPfPj': 14426207819,
#   'dataRegistro': '2010-12-24T14:16:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLA MENDES MARQUES'},
#  {'nrPfPj': 15312736880,
#   'dataRegistro': '2006-03-16T11:26:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS AGUIAR NETO'},
#  {'nrPfPj': 64553027100,
#   'dataRegistro': '2020-10-26T08:39:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO CARNEIRO RANGEL DE CASTRO'},
#  {'nrPfPj': 8456029777,
#   'dataRegistro': '2015-02-27T10:38:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO DA SILVA JUNIOR'},
#  {'nrPfPj': 10588581739,
#   'dataRegistro': '2014-11-18T11:05:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO DE FIGUEIREDO TRINDADE NETO'},
#  {'nrPfPj': 88870529720,
#   'dataRegistro': '2015-07-07T11:06:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO GUIDI DA SILVA'},
#  {'nrPfPj': 18419241806,
#   'dataRegistro': '2008-07-24T15:20:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO HEITOR DE FARIAS MAGGIOLI FILHO'},
#  {'nrPfPj': 7508651804,
#   'dataRegistro': '2006-02-13T17:09:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO MANSUR LEVY'},
#  {'nrPfPj': 8256834838,
#   'dataRegistro': '2010-09-10T13:55:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO MIRANDA'},
#  {'nrPfPj': 3247421858,
#   'dataRegistro': '2011-07-29T14:04:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO PAONE CARDILLO'},
#  {'nrPfPj': 20968957668,
#   'dataRegistro': '2012-09-06T15:52:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO PEREIRA'},
#  {'nrPfPj': 13266604890,
#   'dataRegistro': '2010-10-08T15:51:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO PEREIRA MARTINS'},
#  {'nrPfPj': 8783327827,
#   'dataRegistro': '2010-03-22T16:12:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO ROSA'},
#  {'nrPfPj': 62469894700,
#   'dataRegistro': '2013-11-13T11:51:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO SARAIVA'},
#  {'nrPfPj': 37556762734,
#   'dataRegistro': '2007-09-03T12:02:00Z',
#   'codigoTipoPessoa': 'PF',
#   'codigoTipoParticipante': 57,
#   'denominacaoSocial': 'CARLOS ALBERTO TORRES DE MELO JUNIOR'},
#  ...]
